# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('prepared_data2.csv', sep=',')
df
# Out:
#        brand  model    year  body    price  car_mileage  fuel  power  \
# 0         11    816  2006.0     7   5350.0        220.0     0    2.0
# 1         29    564  2017.0     7  17000.0        211.0     0    2.0
# 2         25    852  2015.0     7  15200.0        157.0     0    2.0
# 3         11    816  2000.0     7   4999.0        300.0     0    2.0
# 4         21    762  2010.0     7  20700.0        682.0     0    3.0
# ...      ...    ...     ...   ...      ...          ...   ...    ...
# 22565     29    527  2011.0     4   8200.0        224.0     0    2.0
# 22566     31    613  2005.0     4   6500.0        200.0     2    1.0
# 22567     31    613  2011.0     4   9300.0        109.0     2    2.0
# 22568     31    613  2011.0     4   9300.0        140.0     1    2.0
# 22569     31    613  2010.0     4   9650.0        147.0     2    2.0
#
#        transmission
# 0                 2
# 1                 2
# 2                 2
# 3                 2
# 4                 1
# ...

# %%
df['age']=(2021-df['year'])
df
# Out:
#        brand  model    year  body    price  car_mileage  fuel  power  \
# 0         11    816  2006.0     7   5350.0        220.0     0    2.0
# 1         29    564  2017.0     7  17000.0        211.0     0    2.0
# 2         25    852  2015.0     7  15200.0        157.0     0    2.0
# 3         11    816  2000.0     7   4999.0        300.0     0    2.0
# 4         21    762  2010.0     7  20700.0        682.0     0    3.0
# ...      ...    ...     ...   ...      ...          ...   ...    ...
# 22565     29    527  2011.0     4   8200.0        224.0     0    2.0
# 22566     31    613  2005.0     4   6500.0        200.0     2    1.0
# 22567     31    613  2011.0     4   9300.0        109.0     2    2.0
# 22568     31    613  2011.0     4   9300.0        140.0     1    2.0
# 22569     31    613  2010.0     4   9650.0        147.0     2    2.0
#
#        transmission   age
# 0                 2  15.0
# 1                 2   4.0
# 2                 2   6.0
# 3                 2  21.0
# ...

# %%
df.describe()
# Out:
#               brand         model          year          body         price  \
# count  22570.000000  22570.000000  22570.000000  22570.000000  22570.000000
# mean      22.168631    481.317856   2009.526572      6.353035  12695.436499
# std       11.876758    236.486838      5.728246      4.327406  10062.735598
# min        0.000000      0.000000   1991.301412      0.000000   1000.000000
# 25%       13.000000    278.000000   2007.000000      3.000000   6300.000000
# 50%       24.000000    510.000000   2010.000000      8.000000   9550.000000
# 75%       31.000000    654.750000   2014.000000     10.000000  15000.000000
# max       40.000000    895.000000   2020.000000     11.000000  49750.707825
#
#         car_mileage          fuel         power  transmission           age
# count  22570.000000  22570.000000  22570.000000  22570.000000  22570.000000
# mean     169.775606      0.917988      2.126871      1.685955     11.473428
# ...

# %%
df['priceLevel']=np.where (df['price']<=12700,0,1)
df
# Out:
#        brand  model    year  body    price  car_mileage  fuel  power  \
# 0         11    816  2006.0     7   5350.0        220.0     0    2.0
# 1         29    564  2017.0     7  17000.0        211.0     0    2.0
# 2         25    852  2015.0     7  15200.0        157.0     0    2.0
# 3         11    816  2000.0     7   4999.0        300.0     0    2.0
# 4         21    762  2010.0     7  20700.0        682.0     0    3.0
# ...      ...    ...     ...   ...      ...          ...   ...    ...
# 22565     29    527  2011.0     4   8200.0        224.0     0    2.0
# 22566     31    613  2005.0     4   6500.0        200.0     2    1.0
# 22567     31    613  2011.0     4   9300.0        109.0     2    2.0
# 22568     31    613  2011.0     4   9300.0        140.0     1    2.0
# 22569     31    613  2010.0     4   9650.0        147.0     2    2.0
#
#        transmission   age  priceLevel
# 0                 2  15.0           0
# 1                 2   4.0           1
# ...

# %%
# Splitting the dataset into the Training set and Test set
a=['brand','model','body','car_mileage','fuel','power','transmission', 'age']
X = df[a]
y = df['priceLevel']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler().fit(X_train)
X_train = sc_X.transform(X_train)
X_test = sc_X.transform(X_test)

# %%
#Feature Selection
# Baseline model
import statsmodels.api as sm
lr = sm.Logit(y_train, X_train).fit()
print(lr.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.409945
#          Iterations 7
#                          Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.359
# Dependent Variable: priceLevel       AIC:              14819.9373
# Date:               2021-12-05 16:02 BIC:              14882.3472
# No. Observations:   18056            Log-Likelihood:   -7402.0
# Df Model:           7                LL-Null:          -11543.
# Df Residuals:       18048            LLR p-value:      0.0000
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     7.0000
# -------------------------------------------------------------------
#           Coef.    Std.Err.      z       P>|z|     [0.025    0.975]
# -------------------------------------------------------------------
# x1       -0.1163     0.0216    -5.3799   0.0000   -0.1587   -0.0739
# x2        0.1488     0.0221     6.7414   0.0000    0.1055    0.1921
# ...

# %%
#x1-3 and x5-8 are important variables

# %%
# Automatic Feature Selection
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
estimator=LogisticRegression(random_state=123)
selector=RFECV(estimator, step=1)
selector=selector.fit(X_train, y_train)
print(selector.n_features_)
print(selector.support_)
print(selector.ranking_)
# Out:
# 6
# [ True  True  True False False  True  True  True]
# [1 1 1 3 2 1 1 1]

# %%
#fitting logistic regression
# Leaving only Selected Features
X_train_select=X_train[:,[False, False,  False,  False, False, True, False, True]]
X_test_select=X_test[:,[False, False,  False,  False, False, True, False, True]]

# %%
X_train_select
# Out:
# array([[-0.17357514, -1.48054142],
#        [-0.17357514,  0.26981419],
#        [-1.55601033, -0.60536362],
#        ...,
#        [-0.17357514,  0.61988531],
#        [ 2.59129524, -0.95543474],
#        [ 1.20886005,  1.32002755]])

# %%
# Fitting Logistic Regression to the Training set 
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression().fit(X_train_select, y_train)

# %%
# Predicting the Test set results
y_pred = lr.predict(X_test_select)
lr.score(X_test_select,y_test).round(3)
# Out:
# 0.852

# %%
#We see that model makes only 14.8% mistakes

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[2653  278]
#  [ 389 1194]]

# %%
#3847 examples recognized correctly, 667 - incorrectly

# %%
# Visualising the Test set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, lr.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('age')
plt.ylabel('power')
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
import pickle
obj = {'X_train': X_train_select, 'X_test': X_test_select,'y_train': y_train,'y_test': y_test}
output = open('data_reg3.pkl', 'wb')
pickle.dump(obj, output, 2)
output.close()
