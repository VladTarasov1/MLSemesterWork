# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('prepared_data2.csv', sep=',')
df
# Out:
#        brand  model    year  body    price  car_mileage  fuel  power  \
# 0         11    816  2006.0     7   5350.0        220.0     0    2.0
# 1         29    564  2017.0     7  17000.0        211.0     0    2.0
# 2         25    852  2015.0     7  15200.0        157.0     0    2.0
# 3         11    816  2000.0     7   4999.0        300.0     0    2.0
# 4         21    762  2010.0     7  20700.0        682.0     0    3.0
# ...      ...    ...     ...   ...      ...          ...   ...    ...
# 22565     29    527  2011.0     4   8200.0        224.0     0    2.0
# 22566     31    613  2005.0     4   6500.0        200.0     2    1.0
# 22567     31    613  2011.0     4   9300.0        109.0     2    2.0
# 22568     31    613  2011.0     4   9300.0        140.0     1    2.0
# 22569     31    613  2010.0     4   9650.0        147.0     2    2.0
#
#        transmission
# 0                 2
# 1                 2
# 2                 2
# 3                 2
# 4                 1
# ...             ...
# 22565             2
# 22566             2
# 22567             2
# 22568             2
# 22569             1
#
# [22570 rows x 9 columns]

# %%
X = df.iloc[:, [True,True,True,True,False,True,True,True,True]]
y = df['price']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
X
# Out:
#        brand  model    year  body  car_mileage  fuel  power  transmission
# 0         11    816  2006.0     7        220.0     0    2.0             2
# 1         29    564  2017.0     7        211.0     0    2.0             2
# 2         25    852  2015.0     7        157.0     0    2.0             2
# 3         11    816  2000.0     7        300.0     0    2.0             2
# 4         21    762  2010.0     7        682.0     0    3.0             1
# ...      ...    ...     ...   ...          ...   ...    ...           ...
# 22565     29    527  2011.0     4        224.0     0    2.0             2
# 22566     31    613  2005.0     4        200.0     2    1.0             2
# 22567     31    613  2011.0     4        109.0     2    2.0             2
# 22568     31    613  2011.0     4        140.0     1    2.0             2
# 22569     31    613  2010.0     4        147.0     2    2.0             1
#
# [22570 rows x 8 columns]

# %%
#Previously we got that the biggest correlation is between price and year. Let's make one-factor model

# %%
f1 = ['year']

from sklearn.linear_model import LinearRegression
sr = LinearRegression().fit(X_train[f1], y_train)

sr.coef_, sr.intercept_
# Out:
# (array([1007.55168771]), -2011971.5460722682)

# %%
#price=1007.55*year-2011971.55

# %%
y_pred = sr.predict(X_test[f1])
sr.score(X_train[f1], y_train).round(3), sr.score(X_test[f1], y_test).round(3)
# Out:
# (0.326, 0.325)

# %%
#year makes 33% of price variability

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train, sr.predict(X_train[f1]), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (8309.69, 8064.5)

# %%
#enormous values

# %%
plt.scatter(X_test['year'], y_test, color = 'red')
plt.plot(X_test['year'], sr.predict(X_test[f1]), 'bo')
plt.title('Price & Year (Test set)')
plt.xlabel('Year')
plt.ylabel('Price, $')
plt.show()

# %%
#Here we see that difference increases as the price increases.

# %%
#Multiple Linear Regression

# %%
mr = LinearRegression().fit(X_train, y_train)
mr.score(X_train, y_train).round(3)
# Out:
# 0.566

# %%
# Visualising the Test set results
plt.scatter(X_test['year'], y_test, color = 'red')
plt.plot(X_test['year'], mr.predict(X_test), 'bo')
plt.title('Price & Year')
plt.xlabel('Year')
plt.ylabel('Price')
plt.show()

# %%
# Checking p-values
import statsmodels.api as sm
X1 = sm.add_constant(X_train)
mr1 = sm.OLS(y_train, X1).fit()
#mr1.pvalues
mr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.566
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                     2947.
# Date:                Sun, 05 Dec 2021   Prob (F-statistic):               0.00
# Time:                        13:03:24   Log-Likelihood:            -1.8460e+05
# No. Observations:               18056   AIC:                         3.692e+05
# Df Residuals:                   18047   BIC:                         3.693e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.806e+06   1.85e+04    -97.615      0.000   -1.84e+06   -1.77e+06
# brand          -24.5304      4.260     -5.759      0.000     -32.880     -16.181
# model            0.8548      0.221      3.864      0.000       0.421       1.288
# year           900.7226      9.188     98.037      0.000     882.714     918.731
# body          -379.9293     12.150    -31.270      0.000    -403.744    -356.114
# car_mileage     -0.4102      0.151     -2.715      0.007      -0.706      -0.114
# fuel          -373.0775     55.956     -6.667      0.000    -482.757    -263.398
# power         5842.3730     70.933     82.364      0.000    5703.337    5981.409
# transmission  -688.2280     69.089     -9.961      0.000    -823.649    -552.807
# ==============================================================================
# Omnibus:                     6533.331   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            26677.012
# Skew:                           1.769   Prob(JB):                         0.00
# Kurtosis:                       7.790   Cond. No.                     7.73e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#car_mileage is not statistical important

# %%
#Polynomial Regression

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
X_train_p = PolynomialFeatures().fit_transform(X_train)
X_test_p = PolynomialFeatures().fit_transform(X_test)

pr = LinearRegression().fit(X_train_p, y_train)

# Getting parameters
pr.coef_, pr.intercept_
# Out:
# (array([-1.57371754e-04,  6.24350945e+03,  3.03720703e+02, -1.79981356e+05,
#          5.97377331e+04,  6.42411821e+01,  1.27461667e+05, -8.30018661e+05,
#          1.31530653e+05,  4.43188579e+00,  1.02451174e-01, -3.21773047e+00,
#         -1.48840535e+00, -6.82894522e-03,  3.10754980e+00, -4.44088767e+00,
#         -8.29172881e+00,  6.75318627e-04, -1.50862678e-01, -2.61760977e-01,
#          1.52452589e-03, -1.11339356e+00, -3.48831954e-01,  8.58157416e-01,
#          4.49603438e+01, -3.00059814e+01, -3.24822145e-02, -6.47918398e+01,
#          4.15075081e+02, -6.89781141e+01,  4.98663963e+01, -4.32781283e-02,
#          7.34272615e+01, -6.81312258e+01, -6.64801985e+00,  3.05135403e-04,
#         -3.50532595e-01, -1.88319673e+00,  4.33891791e-01,  1.44705202e+03,
#         -8.79790949e+02,  4.12779690e+02,  6.80664622e+02, -2.99692196e+02,
#          1.51998782e+03]),
#  180130433.06077054)

# %%
# Predicting the Test set results
y_pred = pr.predict(X_test_p)

# Coefficient of determination R^2
pr.score(X_train_p, y_train).round(3)
# Out:
# 0.717

# %%
#R^2 is much better as for multiple linear regression and linear one

# %%
# Mean squared error
mean_squared_error(y_train, pr.predict(X_train_p), squared=False).round(2), mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# (5387.17, 5261.49)

# %%
#MSE decreased

# %%
# Visualising the Test set results
plt.scatter(X_test['year'], y_test, color = 'red')
plt.plot(X_test['year'], pr.predict(X_test_p), 'bo')
plt.title('Price vs year (Test set)')
plt.xlabel('year')
plt.ylabel('Price')
plt.show()

# %%
import pickle
obj = {'X_train': X_train, 'X_test': X_test,'y_train': y_train,'y_test': y_test}
output = open('data_reg.pkl', 'wb')
pickle.dump(obj, output, 2)
output.close()
